# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
# %matplotlib inline

# %%
#Make a map of carbon dioxide emissions by state, with low emissions 
#being light orange and high emissions being orange.

# %%
df = pd.read_csv("Total Carbon Dioxide Emissions-StateRankings.csv")
df
# Out:
#     Rank State  Total Carbon Dioxide Emissions, million metric tons  \
# 0      1    TX                                              642.0
# 1      2    CA                                              358.0
# 2      3    PA                                              245.0
# 3      4    IL                                              234.0
# 4      5    OH                                              232.0
# 5      6    FL                                              228.0
# 6      7    LA                                              218.0
# 7      8    IN                                              207.0
# 8      9    NY                                              170.0
# 9     10    MI                                              163.0
# 10    11    GA                                              140.0
# 11    12    KY                                              139.0
# 12    13    MO                                              132.0
# ...

# %%
states = gpd.read_file("cb_2016_us_state_500k/cb_2016_us_state_500k.shp")
states.head()
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD        NAME STATEFP  \
# 0  0400000US01   131173688951    4593686489    01   00     Alabama      01
# 1  0400000US02  1477946266785  245390495931    02   00      Alaska      02
# 2  0400000US04   294198560125    1027346486    04   00     Arizona      04
# 3  0400000US05   134771517596    2960191698    05   00    Arkansas      05
# 4  0400000US06   403501101370   20466718403    06   00  California      06
#
#     STATENS STUSPS                                           geometry
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
states.crs
# Out:
# {'init': 'epsg:4269'}

# %%
states['Dioxide Emissions'] = ''

# %%
states.set_value(0, 'Dioxide Emissions', 123.0)
states.set_value(1, 'Dioxide Emissions', 35.0)
states.set_value(2, 'Dioxide Emissions', 93.0)
states.set_value(3, 'Dioxide Emissions', 69.0)
states.set_value(4, 'Dioxide Emissions', 358.0)
states.set_value(5, 'Dioxide Emissions', 92.0)
states.set_value(6, 'Dioxide Emissions', 35.0)
states.set_value(7, 'Dioxide Emissions', 13.0)
states.set_value(8, 'Dioxide Emissions', 3.0)
states.set_value(9, 'Dioxide Emissions', 140.0)
states.set_value(10, 'Dioxide Emissions', 18.0)
states.set_value(11, 'Dioxide Emissions', 17.0)
states.set_value(12, 'Dioxide Emissions', 234.0)
states.set_value(13, 'Dioxide Emissions', 207.0)
states.set_value(14, 'Dioxide Emissions', 82.0)
states.set_value(15, 'Dioxide Emissions', 70.0)
states.set_value(16, 'Dioxide Emissions', 62.0)
states.set_value(17, 'Dioxide Emissions', 95.0)
states.set_value(18, 'Dioxide Emissions', 64.0)
states.set_value(19, 'Dioxide Emissions', 32.0)
states.set_value(20, 'Dioxide Emissions', 37.0)
states.set_value(21, 'Dioxide Emissions', 114.0)
states.set_value(22, 'Dioxide Emissions', 50.0)
states.set_value(23, 'Dioxide Emissions', 59.0)
states.set_value(24, 'Dioxide Emissions', 105.0)
states.set_value(25, 'Dioxide Emissions', 245.0)
states.set_value(26, 'Dioxide Emissions', 75.0)
states.set_value(27, 'Dioxide Emissions', 15.0)
states.set_value(28, 'Dioxide Emissions', 65.0)
states.set_value(29, 'Dioxide Emissions', 6.0)
states.set_value(30, 'Dioxide Emissions', 98.0)
states.set_value(31, 'Dioxide Emissions', 101.0)
states.set_value(34, 'Dioxide Emissions', 228.0)
states.set_value(35, 'Dioxide Emissions', 139.0)
states.set_value(36, 'Dioxide Emissions', 218.0)
states.set_value(37, 'Dioxide Emissions', 17.0)
states.set_value(38, 'Dioxide Emissions', 64.0)
states.set_value(39, 'Dioxide Emissions', 163.0)
states.set_value(40, 'Dioxide Emissions', 132.0)
states.set_value(41, 'Dioxide Emissions', 52.0)
states.set_value(42, 'Dioxide Emissions', 15.0)
states.set_value(43, 'Dioxide Emissions', 170.0)
states.set_value(44, 'Dioxide Emissions', 127.0)
states.set_value(45, 'Dioxide Emissions', 232.0)
states.set_value(46, 'Dioxide Emissions', 38.0)
states.set_value(47, 'Dioxide Emissions', 11.0)
states.set_value(48, 'Dioxide Emissions', 104.0)
states.set_value(49, 'Dioxide Emissions', 642.0)
states.set_value(50, 'Dioxide Emissions', 104.0)
states.set_value(51, 'Dioxide Emissions', 73.0)
states.set_value(52, 'Dioxide Emissions', 101.0)
# Out:
#        AFFGEOID          ALAND        AWATER GEOID LSAD  \
# 0   0400000US01   131173688951    4593686489    01   00
# 1   0400000US02  1477946266785  245390495931    02   00
# 2   0400000US04   294198560125    1027346486    04   00
# 3   0400000US05   134771517596    2960191698    05   00
# 4   0400000US06   403501101370   20466718403    06   00
# 5   0400000US08   268429343790    1175112870    08   00
# 6   0400000US09    12542638347    1815476291    09   00
# 7   0400000US10     5047194742    1398720828    10   00
# 8   0400000US11      158364992      18633403    11   00
# 9   0400000US13   149169848456    4741100880    13   00
# 10  0400000US15    16634100855   11777698394    15   00
# 11  0400000US16   214042908012    2398669593    16   00
# 12  0400000US17   143788697679    6206693598    17   00
# 13  0400000US18    92790545247    1536767065    18   00
# 14  0400000US19   144667643793    1077808017    19   00
# 15  0400000US20   211753253104    1346235678    20   00
# ...

# %%
states.set_index('NAME', inplace=True)

# %%
states.dtypes
# Out:
# AFFGEOID             object
# ALAND                 int64
# AWATER                int64
# GEOID                object
# LSAD                 object
# STATEFP              object
# STATENS              object
# STUSPS               object
# geometry             object
# Dioxide Emissions    object
# dtype: object

# %%
states = states.convert_objects(convert_numeric=True)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
states.dtypes
# Out:
# AFFGEOID              object
# ALAND                  int64
# AWATER                 int64
# GEOID                  int64
# LSAD                   int64
# STATEFP                int64
# STATENS                int64
# STUSPS                object
# geometry              object
# Dioxide Emissions    float64
# dtype: object

# %%
states.dropna(subset=['Dioxide Emissions'], inplace=True)

# %%
states.plot(column='Dioxide Emissions', cmap='Oranges')
