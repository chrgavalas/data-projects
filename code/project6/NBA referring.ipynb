# %%
import pandas as pd

# %%
df = pd.read_csv("all_games.csv")

# %%
df.shape
# Out:
# (16300, 24)

# %%
wrong_calls = ['INC', 'IC']

# %%
df.date = df.date.astype(str)

# %%
df_2016 = df[df.date.str.contains('2016')]

# %%
df_2017 = df[df.date.str.contains('2017')]

# %%
df_2016_in = df_2016.loc[df_2016['review_decision'].isin(wrong_calls)]

# %%
df_2017_in = df_2017.loc[df_2017['review_decision'].isin(wrong_calls)]

# %%
df_2016_in.shape
# Out:
# (797, 24)

# %%
df_2017_in.shape
# Out:
# (340, 24)

# %%
df['review_decision'].value_counts()
# Out:
# CNC    8486
# CC     5272
# INC    1425
# IC      176
# Name: review_decision, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['review_decision'].sort_values(ascending=True).value_counts()
# Out:
# CNC    8486
# CC     5272
# INC    1425
# IC      176
# Name: review_decision, dtype: int64

# %%
df['review_decision'].sort_values(ascending=True).value_counts().plot(kind='bar', color='red', title='Distribution of calls')

# %%
df_incorrect = df.loc[df['review_decision'].isin(wrong_calls)]

# %%
df_incorrect.disadvantaged_team.value_counts()
# Out:
# HOU    72
# DAL    70
# WAS    67
# UTA    67
# CLE    66
# CHI    62
# NOP    61
# TOR    60
# MIN    59
# ATL    58
# IND    58
# POR    56
# MEM    56
# MIA    56
# NYK    56
# BOS    55
# PHI    50
# OKC    49
# GSW    48
# PHO    48
# MIL    46
# DEN    46
# LAC    45
# SAC    44
# CHA    44
# SAS    40
# ORL    39
# BKN    38
# LAL    32
# DET    31
# ARL     1
# Name: disadvantaged_team, dtype: int64

# %%
df_incorrect.home.value_counts().sum()
# Out:
# 1601

# %%
df_incorrect.away.value_counts().sum()
# Out:
# 1601

# %%
#df_incorrect = df_incorrect.seconds_left.astype(int)

# %%
df_incorrect
# Out:
#       period            time  seconds_left                        call_type  \
# 9         Q5         0:03:54         234.0            Foul: Double Personal
# 13        Q5         0:01:02          62.0                  Foul: Offensive
# 14        Q5         0:01:01          61.0                   Foul: Personal
# 25        Q4  0:00:24.800000          24.8              Turnover: Traveling
# 26        Q4  0:00:22.600000          22.6          Turnover: Out of Bounds
# 36        Q4         0:01:08          68.0                 Foul: Loose Ball
# 52        Q4         0:01:20          80.0                   Foul: Shooting
# 57        Q4         0:01:01          61.0              Turnover: Traveling
# 58        Q4         0:01:00          60.0                   Foul: Personal
# 61        Q4  0:00:16.300000          16.3                 Foul: Loose Ball
# 83        Q4  0:00:13.200000          13.2              Turnover: Traveling
# ...

# %%
df_last10 = df_incorrect[df_incorrect.seconds_left <=10]

# %%
df_10to60 = df_incorrect[(df_incorrect['seconds_left'] >= 10) & (df_incorrect['seconds_left'] <= 60)]

# %%
df_61to120 = df_incorrect[(df_incorrect['seconds_left'] > 60) & (df_incorrect['seconds_left'] <= 120)]

# %%
df_last60 = df_incorrect[df_incorrect.seconds_left <=60]

# %%
df_last5 = df_incorrect[df_incorrect.seconds_left <5]

# %%
df_last3 = df_incorrect[df_incorrect.seconds_left <3]

# %%
df_last2 = df_incorrect[df_incorrect.seconds_left <2]

# %%
last_10_decisions = df_last10.groupby('call_type')['review_decision'].size()

# %%
last_10_decisions.value_counts().sort_values(ascending=True).tail(10).plot(kind='barh', figsize=[10,6], colormap='winter')

# %%
df_10to60.review_decision.value_counts()
# Out:
# INC    621
# IC      71
# Name: review_decision, dtype: int64

# %%
df_61to120.review_decision.value_counts()
# Out:
# INC    538
# IC      63
# Name: review_decision, dtype: int64

# %%
df_last60.review_decision.value_counts()
# Out:
# INC    778
# IC      90
# Name: review_decision, dtype: int64

# %%
df_last10.review_decision.value_counts()
# Out:
# INC    159
# IC      19
# Name: review_decision, dtype: int64

# %%
df_last5.review_decision.value_counts()
# Out:
# INC    76
# IC     11
# Name: review_decision, dtype: int64

# %%
df_last3.review_decision.value_counts()
# Out:
# INC    41
# IC      9
# Name: review_decision, dtype: int64

# %%
df_last2.review_decision.value_counts()
# Out:
# INC    20
# IC      6
# Name: review_decision, dtype: int64

# %%
import matplotlib.pyplot as pl

# %%
df_incorrect['time_clusters'] = pd.cut(df_incorrect.seconds_left, bins=[g for g in range(10, 60, 120)], include_lowest=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-065536c93ffc> in <module>()
# ----> 1 df_incorrect['time_clusters'] = pd.cut(df_incorrect.seconds_left, bins=[g for g in range(10, 60, 120)], include_lowest=True)
#       2 df.head()
#
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest)
#     134                               precision=precision,
#     135                               include_lowest=include_lowest,
# --> 136                               dtype=dtype)
#     137
#     138     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
# ...

# %%
df_incorrect.seconds_left.hist()

# %%
df_incorrect['disadvantaged_player'].sort_values().value_counts().head(5).plot(kind='barh', color='pink', title='Players mostly disadvantaged by refs')

# %%
df_incorrect['committing_player'].sort_values().value_counts().head(5).plot(kind='barh', color='blue', title='Players mostly advantaged by refs')

# %%
df_incorrect['disadvantaged_player'].sort_values().value_counts()
# Out:
# James Harden             21
# Isaiah Thomas            17
# Andrew Wiggins           17
# Gordon Hayward           16
# Paul George              16
# Kemba Walker             15
# LeBron James             15
# Wesley Matthews          14
# DeMarcus Cousins         14
# Anthony Davis            13
# Paul Millsap             13
# Dwyane Wade              13
# Giannis Antetokounmpo    13
# Jimmy Butler             13
# Mike Conley              12
# George Hill              12
# Damian Lillard           12
# Dirk Nowitzki            11
# John Wall                11
# PJ Tucker                11
# Danilo Gallinari         10
# Rudy Gobert              10
# Kyrie Irving             10
# Nikola Vucevic           10
# Russell Westbrook        10
# Andre Iguodala            9
# Jeff Teague               9
# Marc Gasol                8
# Kyle Lowry                8
# Kent Bazemore             8
#                          ..
# Trevor Booker             1
# Derrick Williams          1
# ...

# %%
import datetime as dt
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df['year'] = df['date'].dt.year

# %%
df.year
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
# 5        2015
# 6        2015
# 7        2015
# 8        2015
# 9        2015
# 10       2015
# 11       2015
# 12       2015
# 13       2015
# 14       2015
# 15       2015
# 16       2015
# 17       2015
# 18       2015
# 19       2015
# 20       2015
# 21       2015
# 22       2015
# 23       2015
# 24       2015
# 25       2015
# 26       2015
# 27       2015
# 28       2015
# 29       2015
#          ...
# 16270    2017
# 16271    2017
# 16272    2017
# 16273    2017
# 16274    2017
# 16275    2017
# 16276    2017
# 16277    2017
# 16278    2017
# 16279    2017
# 16280    2017
# 16281    2017
# 16282    2017
# 16283    2017
# 16284    2017
# 16285    2017
# 16286    2017
# 16287    2017
# 16288    2017
# 16289    2017
# 16290    2017
# 16291    2017
# 16292    2017
# 16293    2017
# 16294    2017
# 16295    2017
# 16296    2017
# 16297    2017
# 16298    2017
# 16299    2017
# ...

# %%
import datetime as dt
df_incorrect['date'] = pd.to_datetime(df_incorrect['date'], errors='coerce')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_incorrect['year'] = df_incorrect['date'].dt.year
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_incorrect.groupby('year')['review_decision'].value_counts().plot(kind='barh')

# %%
df_incorrect['time_left'] = pd.to_datetime(df.seconds_left, format="%Y-%m-%d").head()
# Out:
# period                          object
# time                            object
# seconds_left                   float64
# call_type                       object
# committing_player               object
# disadvantaged_player            object
# review_decision                 object
# comment                         object
# video                           object
# game_id                         object
# play_id                         object
# away                            object
# home                            object
# date                    datetime64[ns]
# ref_1                           object
# ref_2                           object
# ref_3                           object
# score_away                     float64
# score_home                     float64
# original_pdf                    object
# box_score_url                   object
# disadvantaged_team              object
# committing_team                 object
# ref_made_call                   object
# ...

# %%
CountStatus = pd.value_counts(df_incorrect['year'].values, sort=True)

# %%
CountStatus.value_counts()
# Out:
# 340    1
# 797    1
# 464    1
# dtype: int64

# %%
CountStatus.plot.barh(title='More incorrect calls last year')

# %%
wrong_types = df_incorrect.groupby('call_type')['review_decision']

# %%
wrong_types.size()
# Out:
# call_type
# Foul: Away from Play                 16
# Foul: Defense 3 Second              119
# Foul: Delay Technical                 1
# Foul: Double Personal                 5
# Foul: Inbound                         2
# Foul: Loose Ball                    216
# Foul: Offensive                     283
# Foul: Personal                      276
# Foul: Punching                        1
# Foul: Shooting                      315
# Foul: Technical                       4
# Instant Replay: Overturn Ruling       1
# Instant Replay: Support Ruling        1
# Other                                 3
# Other: Held Ball                      1
# Stoppage: Out-of-Bounds               3
# Turnover: 10 Second Violation         2
# Turnover: 24 Second Violation         4
# Turnover: 3 Second Violation         43
# Turnover: 5 Second Inbound           17
# Turnover: 5 Second Violation          1
# Turnover: 8 Second Violation          1
# Turnover: Backcourt Turnover          2
# ...

# %%
wrong_types.value_counts()
# Out:
# call_type                         review_decision
# Foul: Away from Play              INC                 15
#                                   IC                   1
# Foul: Defense 3 Second            INC                119
# Foul: Delay Technical             INC                  1
# Foul: Double Personal             INC                  4
#                                   IC                   1
# Foul: Inbound                     INC                  2
# Foul: Loose Ball                  INC                202
#                                   IC                  14
# Foul: Offensive                   INC                275
#                                   IC                   8
# Foul: Personal                    INC                222
#                                   IC                  54
# Foul: Punching                    INC                  1
# Foul: Shooting                    INC                243
#                                   IC                  72
# ...

# %%
wrong_types.value_counts().sort_values(ascending=True).tail(10).plot(kind='barh', figsize=[10,6], colormap='winter', title='Which incorrect calls occur most often at the end of close games')
